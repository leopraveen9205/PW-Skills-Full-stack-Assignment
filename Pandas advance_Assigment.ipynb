# %%
"""
1. List any five functions of the pandas library with execution.

head()

Shows the first n rows of a DataFrame (default n=5).

"""
import pandas as pd

data = {
    'Name': ['Alice', 'Bob', 'Claire', 'David'],
    'Age': [25, 30, 27, 22],
    'Gender': ['Female', 'Male', 'Female', 'Male']
}
df = pd.DataFrame(data)

# Show first 3 rows
print(df.head(3))
""" 2. Info() """
print(df.info())

###### 3. describe()
print(df.describe())

######  4. sort_values()
sorted_df = df.sort_values(by='Age', ascending=False)
print(sorted_df)
########## 5. drop()
dropped_df  = df.drop(columns=['Gender'])       
print(dropped_df)

# %%
"""
2. Given a Pandas DataFrame df with columns 'A', 'B', and 'C', write a Python function to re-index the
DataFrame with a new index that starts from 1 and increments by 2 for each row.

"""
import pandas as pd

# Sample DataFrame
df = pd.DataFrame({
    'A': [10, 20, 30],
    'B': [40, 50, 60],
    'C': [70, 80, 90]
})

# Function to re-index DataFrame
def custom_reindex(df):
    # Create new index starting from 1, increment by 2
    new_index = list(range(1, 2*len(df), 2))
    # Assign new index to the DataFrame
    df.index = new_index
    return df

# Apply the function
df_new = custom_reindex(df)
print(df_new)

# %%
"""
Q3. You have a Pandas DataFrame df with a column named 'Values'. Write a Python function that
iterates over the DataFrame and calculates the sum of the first three values in the 'Values' column. The
function should print the sum to the console.

"""
import pandas as pd

# Sample DataFrame
df = pd.DataFrame({
    'Values': [10, 20, 30, 40, 50]
})

# Function to calculate the sum of the first three values
def sum_first_three(df):
    total = 0
    # Iterate over the 'Values' column
    for i, value in enumerate(df['Values']):
        if i < 3:      # Only consider the first three elements
            total += value
        else:
            break
    print("Sum of first three values:", total)

# Call the function
sum_first_three(df)

# %%
"""
4. Given a Pandas DataFrame df with a column 'Text', write a Python function to create a new column
'Word_Count' that contains the number of words in each row of the 'Text' column.

"""
import pandas as pd

# Sample DataFrame
df = pd.DataFrame({
    'Text': [
        "Hello world",
        "Pandas is great for data analysis",
        "Python programming"
    ]
})

# Function to add 'Word_Count' column
def add_word_count(df):
    # Use apply() to count words in each row
    df['Word_Count'] = df['Text'].apply(lambda x: len(x.split()))
    return df

# Apply the function
df = add_word_count(df)

# Print the updated DataFrame
print(df)

# %%
"""
Q5. How are DataFrame.size() and DataFrame.shape() different?
DataFrame.size

What it does: Returns the total number of elements in the DataFrame (i.e., number of rows × number of columns).

Type of output: Integer.
"""

# %%
import pandas as pd

df = pd.DataFrame({
    'A': [1, 2, 3],
    'B': [4, 5, 6],
    'C': [7, 8, 9]
})

print("Size of DataFrame:", df.size)

# %%
""" DataFrame.shape

What it does: Returns a tuple representing the dimensions of the DataFrame: (number of rows, number of columns).

Type of output: Tuple."""
print("Shape of DataFrame:", df.shape)

# %%
"""
Q6. Which function of pandas do we use to read an excel file?

"""
import pandas as pd

# Read an Excel file into a DataFrame
df = pd.read_excel('example.xlsx')

# Print the first 5 rows
print(df.head())

# %%
"""
Q7. You have a Pandas DataFrame df that contains a column named 'Email' that contains email
addresses in the format 'username@domain.com'. Write a Python function that creates a new column
'Username' in df that contains only the username part of each email address.
The username is the part of the email address that appears before the '@' symbol. For example, if the
email address is 'john.doe@example.com', the 'Username' column should contain 'john.doe'. Your
function should extract the username from each email address and store it in the new 'Username'
column.

"""
import pandas as pd

# Sample DataFrame
df = pd.DataFrame({
    'Email': ['john.doe@example.com', 'alice.smith@test.com', 'bob123@domain.org']
})

# Function to create 'Username' column
def extract_username(df):
    # Use apply with a lambda to split each email at '@' and take the first part
    df['Username'] = df['Email'].apply(lambda x: x.split('@')[0])
    return df

# Apply the function
df = extract_username(df)

# Print the updated DataFrame
print(df)

# %%
"""
8. You have a Pandas DataFrame df with columns 'A', 'B', and 'C'. Write a Python function that selects
all rows where the value in column 'A' is greater than 5 and the value in column 'B' is less than 10. The
function should return a new DataFrame that contains only the selected rows.

"""
import pandas as pd

# Sample DataFrame
df = pd.DataFrame({
    'A': [3, 8, 6, 2, 9],
    'B': [5, 2, 9, 3, 1],
    'C': [1, 7, 4, 5, 2]
})

# Function to select rows based on conditions
def select_rows(df):
    # Boolean condition: A > 5 and B < 10
    filtered_df = df[(df['A'] > 5) & (df['B'] < 10)]
    return filtered_df

# Apply the function
new_df = select_rows(df)

# Print the new DataFrame
print(new_df)

# %%
"""
Q9. Given a Pandas DataFrame df with a column 'Values', write a Python function to calculate the mean,
median, and standard deviation of the values in the 'Values' column.
"""
import pandas as pd

# Sample DataFrame
df = pd.DataFrame({
    'Values': [10, 20, 30, 40, 50]
})

# Function to calculate statistics
def calculate_stats(df):
    mean_val = df['Values'].mean()
    median_val = df['Values'].median()
    std_val = df['Values'].std()
    
    print("Mean:", mean_val)
    print("Median:", median_val)
    print("Standard Deviation:", std_val)

# Call the function
calculate_stats(df)

# %%
"""
Q10. Given a Pandas DataFrame df with a column 'Sales' and a column 'Date', write a Python function to
create a new column 'MovingAverage' that contains the moving average of the sales for the past 7 days
for each row in the DataFrame. The moving average should be calculated using a window of size 7 and
should include the current day.

"""
import pandas as pd

# Sample DataFrame
df = pd.DataFrame({
    'Date': pd.date_range(start='2025-12-01', periods=10, freq='D'),
    'Sales': [100, 150, 200, 130, 170, 160, 180, 190, 210, 200]
})

# Function to add 7-day moving average
def add_moving_average(df, window=7):
    # Calculate moving average using rolling window
    df['MovingAverage'] = df['Sales'].rolling(window=window, min_periods=1).mean()
    return df

# Apply the function
df = add_moving_average(df)

# Print the updated DataFrame
print(df)

# %%
"""
Q11. You have a Pandas DataFrame df with a column 'Date'. Write a Python function that creates a new
column 'Weekday' in the DataFrame. The 'Weekday' column should contain the weekday name (e.g.
Monday, Tuesday) corresponding to each date in the 'Date' column.
For example, if df contains the following values:
Date
0 2023-01-01
1 2023-01-02
2 2023-01-03
3 2023-01-04
4 2023-01-05
Your function should create the following DataFrame:

Date Weekday
0 2023-01-01 Sunday
1 2023-01-02 Monday
2 2023-01-03 Tuesday
3 2023-01-04 Wednesday
4 2023-01-05 Thursday
The function should return the modified DataFrame.
"""
import pandas as pd

# Sample DataFrame
df = pd.DataFrame({
    'Date': ['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04', '2023-01-05']
})

# Function to add 'Weekday' column
def add_weekday_column(df):
    # Ensure 'Date' column is in datetime format
    df['Date'] = pd.to_datetime(df['Date'])
    # Create 'Weekday' column with weekday names
    df['Weekday'] = df['Date'].dt.day_name()
    return df

# Apply the function
df = add_weekday_column(df)

# Print the updated DataFrame
print(df)

# %%
"""
Q12. Given a Pandas DataFrame df with a column 'Date' that contains timestamps, write a Python
function to select all rows where the date is between '2023-01-01' and '2023-01-31'.
"""
import pandas as pd

# Sample DataFrame
df = pd.DataFrame({
    'Date': pd.to_datetime([
        '2023-01-01', '2023-01-05', '2023-01-15',
        '2023-02-01', '2023-02-10'
    ]),
    'Value': [10, 20, 30, 40, 50]
})

# Function to select rows within a date range
def select_date_range(df, start_date='2023-01-01', end_date='2023-01-31'):
    # Ensure 'Date' column is datetime
    df['Date'] = pd.to_datetime(df['Date'])
    # Apply boolean indexing
    filtered_df = df[(df['Date'] >= start_date) & (df['Date'] <= end_date)]
    return filtered_df

# Apply the function
df_filtered = select_date

# %%
"""
Q13. To use the basic functions of pandas, what is the first and foremost necessary library that needs to
be imported?
"""
import pandas as pd
