# %%
## 1. In Python, comments are used to explain code and make it easier to understand. They are ignored by the Python interpreter.
"""
1. Single-line Comment

Use the # symbol.

2. Multi-line Comment (Not officially, but commonly used)

Python does not have a dedicated multi-line comment syntax like some languages, but you can use triple-quoted strings (''' ... ''' or """ ... """) as multi-line comments when they are not assigned to any variable.

3. Docstring (Documentation String)

A docstring is also written using triple quotes, but its purpose is to document functions, classes, and modules."""

# %%
""" ## 2. What are variables in Python?

A variable is:

A name given to a value

A reference to data stored in memory

Created automatically when you assign a value (no need to declare type) 

Example:
x = 10  # Here, 'x' is a variable that holds the integer value 10 """

# %%
""" 3 . How do you convert one data type to another in Python? 
In Python, converting one data type to another is called type casting or type conversion.
Python provides built-in functions to convert between data types. For example:  x = int(10.8)      # 10
y = int("25") """

# %%
""" 4.How do you write and execute a Python script from the command line?
Create a Python Script File and save it with a .py extension.
Open Command Line Interface (CLI).
Navigate to the Directory.
Run the Script using the command: python script_name.py

"""

# %%
""" 5. Given a list my_list = [1, 2, 3, 4, 5], write the code to slice the list and obtain the sub-list [2, 3].

my_list = [1, 2, 3, 4, 5]
sub_list = my_list[1:3] 
print(sub_list) 
"""

# %%
""" Q6. What is a complex number in mathematics, and how is it represented in Python?

A complex number is a number that has both a real part and an imaginary part. It is typically represented in the form a + bi, where 'a' is the real part, 
'b' is the imaginary part, and 'i' is the imaginary unit, which satisfies the equation i² = -1.

"""

# %%
""" 7. What is the correct way to declare a variable named age and assign the value 25 to it?
age = 25
"""

# %%
""" 8. Declare a variable named price and assign the value 9.99 to it. What data type does this variable
belong to?

price = 9.99
The variable 'price' belongs to the float data type.

"""

# %%
""" 9. Create a variable named name and assign your full name to it as a string. How would you print the
value of this variable?
name = "John Doe"
print(name) 

"""

# %%
""" 10. Given the string "Hello, World!", extract the substring "World".
full_string = "Hello, World!"
substring = full_string[7:12]   """

# %%
""" Q11. Create a variable named "is_student" and assign it a boolean value indicating whether you are
currently a student or not. 

is_student = True
# or
is_student = False

"""
